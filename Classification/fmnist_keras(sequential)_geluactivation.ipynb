# %% [markdown]
# <a href="https://colab.research.google.com/github/GunH-colab/basicsML/blob/master/Classification/fmnist_keras(sequential)_geluactivation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***How to use Gelu activation to train your model***

# %% [markdown]
# *  **Fashion MNIST**
# *  **Sequential API**
# *   **Gelu activation (Custom)**
# *   **Batch Normalisation**

# %%
#importing all the necessary libraries

import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
# fetching the dataset

(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
# official class_names array --> https://github.com/zalandoresearch/fashion-mnist 

class_names = ['T-shirt/top', 
               'Trouser', 
               'Pullover', 
               'Dress', 
               'Coat',
               'Sandal', 
               'Shirt', 
               'Sneaker', 
               'Bag', 
               'Ankle boot']

# %%
# viewing the images(tracing pixel density)

plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.show()

# %%
# rechecking the fetched dataset on grayscale

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])

# %%
#viewing the dimensions of every segment of the dataset

print("",train_images.shape,"\n", train_labels.shape,"\n", test_images.shape,"\n", test_labels.shape,"\n")
# Out:
#  (60000, 28, 28)
#  (60000,)
#  (10000, 28, 28)
#  (10000,)

# %%
def gelu(x):
    return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))
get_custom_objects().update({'gelu': Activation(gelu)})

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(500, activation="gelu"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(150, activation="gelu"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation="softmax")
])

# %%
#compiling the model

model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])

# %%
[(var.name, var.trainable) for var in model.layers[1].variables]
# Out:
# [('batch_normalization/gamma:0', True),
#  ('batch_normalization/beta:0', True),
#  ('batch_normalization/moving_mean:0', False),
#  ('batch_normalization/moving_variance:0', False)]

# %%
model.layers[1].updates
# Out:
# WARNING:tensorflow:From <ipython-input-11-11fe563bf3e2>:1: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# []

# %%
#summary of the model

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# dense (Dense)                (None, 500)               392500
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 500)               2000
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               75150
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 150)               600
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1510
# =================================================================
# Total params: 474,896
# Trainable params: 472,028
# Non-trainable params: 2,868
# _________________________________________________________________

# %%
#training the model (parent step) 

EPOCHS = int(input()) #<-- enter number of epochs

history = model.fit(train_images, train_labels, epochs=EPOCHS, validation_split=0.2)
# Out:
# 100
# Epoch 1/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.5189 - accuracy: 0.8187 - val_loss: 0.3947 - val_accuracy: 0.8622
# Epoch 2/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.3821 - accuracy: 0.8613 - val_loss: 0.3574 - val_accuracy: 0.8715
# Epoch 3/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.3388 - accuracy: 0.8780 - val_loss: 0.3387 - val_accuracy: 0.8784
# Epoch 4/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.3140 - accuracy: 0.8849 - val_loss: 0.3274 - val_accuracy: 0.8815
# Epoch 5/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2907 - accuracy: 0.8946 - val_loss: 0.3224 - val_accuracy: 0.8868
# Epoch 6/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2705 - accuracy: 0.9013 - val_loss: 0.3218 - val_accuracy: 0.8855
# Epoch 7/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2542 - accuracy: 0.9081 - val_loss: 0.3257 - val_accuracy: 0.8852
# Epoch 8/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2411 - accuracy: 0.9122 - val_loss: 0.3080 - val_accuracy: 0.8916
# Epoch 9/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2295 - accuracy: 0.9170 - val_loss: 0.3290 - val_accuracy: 0.8887
# Epoch 10/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2156 - accuracy: 0.9223 - val_loss: 0.3200 - val_accuracy: 0.8908
# Epoch 11/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2062 - accuracy: 0.9259 - val_loss: 0.3172 - val_accuracy: 0.8895
# Epoch 12/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1978 - accuracy: 0.9273 - val_loss: 0.3380 - val_accuracy: 0.8896
# Epoch 13/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1871 - accuracy: 0.9327 - val_loss: 0.3277 - val_accuracy: 0.8924
# Epoch 14/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1800 - accuracy: 0.9344 - val_loss: 0.3414 - val_accuracy: 0.8893
# Epoch 15/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1692 - accuracy: 0.9393 - val_loss: 0.3225 - val_accuracy: 0.8913
# Epoch 16/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1608 - accuracy: 0.9415 - val_loss: 0.3312 - val_accuracy: 0.8886
# Epoch 17/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1559 - accuracy: 0.9431 - val_loss: 0.3345 - val_accuracy: 0.8917
# Epoch 18/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1474 - accuracy: 0.9472 - val_loss: 0.3702 - val_accuracy: 0.8944
# Epoch 19/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1420 - accuracy: 0.9497 - val_loss: 0.3370 - val_accuracy: 0.8899
# Epoch 20/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1343 - accuracy: 0.9528 - val_loss: 0.3435 - val_accuracy: 0.8899
# Epoch 21/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1314 - accuracy: 0.9525 - val_loss: 0.3544 - val_accuracy: 0.8887
# Epoch 22/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.1247 - accuracy: 0.9560 - val_loss: 0.3477 - val_accuracy: 0.8933
# Epoch 23/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1193 - accuracy: 0.9566 - val_loss: 0.3667 - val_accuracy: 0.8881
# Epoch 24/100
# 1500/1500 [==============================] - 14s 9ms/step - loss: 0.1174 - accuracy: 0.9580 - val_loss: 0.3752 - val_accuracy: 0.8889
# Epoch 25/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1097 - accuracy: 0.9610 - val_loss: 0.3608 - val_accuracy: 0.8918
# Epoch 26/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1071 - accuracy: 0.9614 - val_loss: 0.3572 - val_accuracy: 0.8942
# Epoch 27/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1022 - accuracy: 0.9630 - val_loss: 0.3714 - val_accuracy: 0.8913
# Epoch 28/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0984 - accuracy: 0.9638 - val_loss: 0.4065 - val_accuracy: 0.8871
# Epoch 29/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0969 - accuracy: 0.9657 - val_loss: 0.3704 - val_accuracy: 0.8955
# Epoch 30/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0886 - accuracy: 0.9693 - val_loss: 0.4046 - val_accuracy: 0.8913
# Epoch 31/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0875 - accuracy: 0.9690 - val_loss: 0.3907 - val_accuracy: 0.8896
# Epoch 32/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0844 - accuracy: 0.9702 - val_loss: 0.3759 - val_accuracy: 0.8937
# Epoch 33/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0796 - accuracy: 0.9727 - val_loss: 0.3851 - val_accuracy: 0.8942
# Epoch 34/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0795 - accuracy: 0.9727 - val_loss: 0.3894 - val_accuracy: 0.8934
# Epoch 35/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0774 - accuracy: 0.9731 - val_loss: 0.3874 - val_accuracy: 0.8928
# Epoch 36/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0711 - accuracy: 0.9749 - val_loss: 0.4111 - val_accuracy: 0.8917
# Epoch 37/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0732 - accuracy: 0.9743 - val_loss: 0.4545 - val_accuracy: 0.8895
# Epoch 38/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0698 - accuracy: 0.9756 - val_loss: 0.3953 - val_accuracy: 0.8944
# Epoch 39/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0661 - accuracy: 0.9768 - val_loss: 0.4210 - val_accuracy: 0.8957
# Epoch 40/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0648 - accuracy: 0.9767 - val_loss: 0.4246 - val_accuracy: 0.8914
# Epoch 41/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0607 - accuracy: 0.9798 - val_loss: 0.4410 - val_accuracy: 0.8927
# Epoch 42/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0602 - accuracy: 0.9797 - val_loss: 0.4075 - val_accuracy: 0.8918
# Epoch 43/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0606 - accuracy: 0.9791 - val_loss: 0.4218 - val_accuracy: 0.8924
# Epoch 44/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0564 - accuracy: 0.9808 - val_loss: 0.4031 - val_accuracy: 0.8936
# Epoch 45/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0559 - accuracy: 0.9810 - val_loss: 0.4309 - val_accuracy: 0.8937
# Epoch 46/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0529 - accuracy: 0.9818 - val_loss: 0.4291 - val_accuracy: 0.8941
# Epoch 47/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0521 - accuracy: 0.9820 - val_loss: 0.4374 - val_accuracy: 0.8936
# Epoch 48/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0504 - accuracy: 0.9822 - val_loss: 0.4318 - val_accuracy: 0.8938
# Epoch 49/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0489 - accuracy: 0.9833 - val_loss: 0.4487 - val_accuracy: 0.8929
# Epoch 50/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0477 - accuracy: 0.9836 - val_loss: 0.4519 - val_accuracy: 0.8920
# Epoch 51/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0490 - accuracy: 0.9831 - val_loss: 0.4531 - val_accuracy: 0.8931
# Epoch 52/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0478 - accuracy: 0.9831 - val_loss: 0.4419 - val_accuracy: 0.8900
# Epoch 53/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0469 - accuracy: 0.9837 - val_loss: 0.4397 - val_accuracy: 0.8950
# Epoch 54/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0423 - accuracy: 0.9860 - val_loss: 0.4444 - val_accuracy: 0.8928
# Epoch 55/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0413 - accuracy: 0.9863 - val_loss: 0.4545 - val_accuracy: 0.8939
# Epoch 56/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0392 - accuracy: 0.9869 - val_loss: 0.4671 - val_accuracy: 0.8923
# Epoch 57/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0398 - accuracy: 0.9870 - val_loss: 0.4707 - val_accuracy: 0.8919
# Epoch 58/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0389 - accuracy: 0.9876 - val_loss: 0.4478 - val_accuracy: 0.8968
# Epoch 59/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0388 - accuracy: 0.9866 - val_loss: 0.4462 - val_accuracy: 0.8952
# Epoch 60/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0391 - accuracy: 0.9866 - val_loss: 0.4638 - val_accuracy: 0.8932
# Epoch 61/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0383 - accuracy: 0.9870 - val_loss: 0.4634 - val_accuracy: 0.8951
# Epoch 62/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0374 - accuracy: 0.9877 - val_loss: 0.4687 - val_accuracy: 0.8939
# Epoch 63/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.4617 - val_accuracy: 0.8946
# Epoch 64/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0361 - accuracy: 0.9880 - val_loss: 0.4670 - val_accuracy: 0.8930
# Epoch 65/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0346 - accuracy: 0.9883 - val_loss: 0.4682 - val_accuracy: 0.8947
# Epoch 66/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0300 - accuracy: 0.9903 - val_loss: 0.4784 - val_accuracy: 0.8932
# Epoch 67/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.5063 - val_accuracy: 0.8941
# Epoch 68/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0311 - accuracy: 0.9898 - val_loss: 0.4899 - val_accuracy: 0.8915
# Epoch 69/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0298 - accuracy: 0.9904 - val_loss: 0.4915 - val_accuracy: 0.8916
# Epoch 70/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0323 - accuracy: 0.9895 - val_loss: 0.4749 - val_accuracy: 0.8963
# Epoch 71/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0286 - accuracy: 0.9907 - val_loss: 0.4983 - val_accuracy: 0.8943
# Epoch 72/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 0.4750 - val_accuracy: 0.8942
# Epoch 73/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0275 - accuracy: 0.9907 - val_loss: 0.4933 - val_accuracy: 0.8928
# Epoch 74/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0269 - accuracy: 0.9911 - val_loss: 0.5198 - val_accuracy: 0.8915
# Epoch 75/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.4970 - val_accuracy: 0.8942
# Epoch 76/100
# 1500/1500 [==============================] - 14s 9ms/step - loss: 0.0256 - accuracy: 0.9916 - val_loss: 0.4978 - val_accuracy: 0.8924
# Epoch 77/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0276 - accuracy: 0.9913 - val_loss: 0.4949 - val_accuracy: 0.8940
# Epoch 78/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0273 - accuracy: 0.9913 - val_loss: 0.4853 - val_accuracy: 0.8933
# Epoch 79/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.4968 - val_accuracy: 0.8951
# Epoch 80/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0265 - accuracy: 0.9912 - val_loss: 0.4963 - val_accuracy: 0.8943
# Epoch 81/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0251 - accuracy: 0.9915 - val_loss: 0.5077 - val_accuracy: 0.8947
# Epoch 82/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0238 - accuracy: 0.9921 - val_loss: 0.5017 - val_accuracy: 0.8953
# Epoch 83/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0227 - accuracy: 0.9926 - val_loss: 0.5062 - val_accuracy: 0.8957
# Epoch 84/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0236 - accuracy: 0.9925 - val_loss: 0.5066 - val_accuracy: 0.8941
# Epoch 85/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0221 - accuracy: 0.9932 - val_loss: 0.5552 - val_accuracy: 0.8916
# Epoch 86/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.5039 - val_accuracy: 0.8929
# Epoch 87/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.5361 - val_accuracy: 0.8925
# Epoch 88/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0216 - accuracy: 0.9932 - val_loss: 0.5089 - val_accuracy: 0.8956
# Epoch 89/100
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0219 - accuracy: 0.9927 - val_loss: 0.5205 - val_accuracy: 0.8950
# Epoch 90/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.5026 - val_accuracy: 0.8935
# Epoch 91/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0206 - accuracy: 0.9940 - val_loss: 0.5239 - val_accuracy: 0.8936
# Epoch 92/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0216 - accuracy: 0.9931 - val_loss: 0.5225 - val_accuracy: 0.8940
# Epoch 93/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.5186 - val_accuracy: 0.8952
# Epoch 94/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0200 - accuracy: 0.9934 - val_loss: 0.5247 - val_accuracy: 0.8953
# Epoch 95/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.5214 - val_accuracy: 0.8943
# Epoch 96/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 0.5340 - val_accuracy: 0.8937
# Epoch 97/100
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0199 - accuracy: 0.9939 - val_loss: 0.5275 - val_accuracy: 0.8943
# Epoch 98/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.5651 - val_accuracy: 0.8949
# Epoch 99/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.5259 - val_accuracy: 0.8965
# Epoch 100/100
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0206 - accuracy: 0.9936 - val_loss: 0.5485 - val_accuracy: 0.8957

# %%
#viewing the losses and accuracies saved in 'history'

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
#testing the model

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.6130 - accuracy: 0.8906
#
# Test accuracy: 0.8906000256538391

# %%
#saving all the predictions of every test_images in 'predictions' array

predictions = model.predict(test_images)

# %%
#viewing an instance of the 'predictions' array

predictions[0]
# Out:
# array([1.2592902e-10, 3.0472647e-09, 2.8043026e-12, 2.1432660e-09,
#        2.4235209e-09, 6.3760510e-08, 4.6447868e-09, 1.2512314e-06,
#        7.7254847e-10, 9.9999869e-01], dtype=float32)

# %%
#taking the max score of a particular prediction

np.argmax(predictions[0])
# Out:
# 9

# %%
#actual label from the dataset[ it macthes with the predicted label in the above cell, hence its a successfull prediction]

test_labels[0]
# Out:
# 9

# %%
#function to view the image and with labels(predicted class, score%, actual class)

def plotImg(i, preds_arr, true_label, img):
    true_label, img = true_label[i], img[i]

    plt.yticks([])
    plt.xticks([])
    plt.imshow(img, cmap=plt.cm.binary)

    pred_label = np.argmax(preds_arr)

    if pred_label == true_label:
        COLOR = 'green'
    else:
        COLOR = 'red'

    plt.xlabel("{} {:0.2f}% ({})".format(class_names[pred_label], 100*np.max(preds_arr), class_names[true_label]), color=COLOR)

# %%
#function to construct bar graphs of the scores of each class

def plotGraph(i, preds_arr, true_label):
    true_label = true_label[i]

    plt.xticks(range(10))
    plt.yticks([])
    plt.ylim([0, 1])
    PLOT = plt.bar(range(10), preds_arr, color="#777777")

# for a successfull prediction color is 'green' else 'red'
    PLOT[np.argmax(preds_arr)].set_color('red')
    PLOT[true_label].set_color('green')

# %%
#packing two funtions in one callable funtion

def plotter(i, preds_arr, test_labels, test_images):
    preds = preds_arr[i]
    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plotImg(i, preds, test_labels, test_images)
    plt.subplot(1,2,2)
    plotGraph(i, preds, test_labels)

# %%
i = int(input()) # <-- get your input here
# Out:
# 5

# %%
# using the function

plotter(i, predictions, test_labels, test_images)

# %%
# either way....

for i in range(20, 30):
    plotter(i, predictions, test_labels, test_images)

# %%
# to produce a mass tight sheet of predictions and their graph

num_rows = int(input())
num_cols = int(input())
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plotImg(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plotGraph(i, predictions[i], test_labels)
plt.tight_layout()
# Out:
# 3
# 5
